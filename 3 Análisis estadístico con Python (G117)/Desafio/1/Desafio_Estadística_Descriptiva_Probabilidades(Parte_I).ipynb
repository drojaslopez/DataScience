# %% [markdown]
# # Desafio Estadística descriptiva y probabilidades (Parte I)
# ## Daniel Rojas Lopez

# %% [markdown]
# ### Ejercicio 1:
#
# 1. Calcular los indicadores estadísticos solicitados, sobre columnas especíﬁcas. (3
# Puntos)

# %%
import pandas as pd


"""El promedio general de los salarios, desviación estándar, quintiles y rango. (hint:
escoge la columna adecuada para comparar)"""

df = pd.read_csv("ds_salaries.csv")
df.head(3)
#df["salary_in_usd"].describe()
# Out:
# count      3755.000000
# mean     137570.389880
# std       63055.625278
# min        5132.000000
# 25%       95000.000000
# 50%      135000.000000
# 75%      175000.000000
# max      450000.000000
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# 2. Calcular indicadores estadísticos, agrupando y ﬁltrando los valores (3 Puntos)

# %%
""" ""Una comparación entre los salarios agrupados por 3 diferentes categorías a tu
elección. ¿Para cuál de ellas las medidas de tendencia central son más representativas?

¿Para cuál son menos representativas? Explica."""

df.groupby('experience_level').salary_in_usd.mean()

# %% [markdown]
# 3. Interpretar los indicadores estadísticos en cada caso, considerando medidas de
# tendencia central y dispersión.(4 Puntos)
