# %% [markdown]
# # Desafio Estadística descriptiva y probabilidades (Parte I)
# ## Daniel Rojas Lopez

# %% [markdown]
# ### Ejercicio 1:
#
# 1. El promedio general de los salarios, desviación estándar, quintiles y rango. (hint:
# escoge la columna adecuada para comparar)

# %%
import pandas as pd


"""El promedio general de los salarios, desviación estándar, quintiles y rango. (hint:
escoge la columna adecuada para comparar)"""

df = pd.read_csv("ds_salaries.csv")
df["salary_in_usd"].describe()
# Out:
# count      3755.000000
# mean     137570.389880
# std       63055.625278
# min        5132.000000
# 25%       95000.000000
# 50%      135000.000000
# 75%      175000.000000
# max      450000.000000
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# 2. Una comparación entre los salarios agrupados por 3 diferentes categorías a tu
# elección. ¿Para cuál de ellas las medidas de tendencia central son más representativas?
#
#  ¿Para cuál son menos representativas? Explica.

# %%
""" ""Una comparación entre los salarios agrupados por 3 diferentes categorías a tu
elección. ¿Para cuál de ellas las medidas de tendencia central son más representativas?

¿Para cuál son menos representativas? Explica."""

df.groupby('experience_level').salary_in_usd.mean()
# Out:
# experience_level
# EN     78546.284375
# EX    194930.929825
# MI    104525.939130
# SE    153051.071542
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# 3. ¿Qué cargos reciben mejores sueldos en las empresas con sede en Estados Unidos?

# %%
""" 3. ¿Qué cargos reciben mejores sueldos en las empresas con sede en Estados Unidos? """

df_usa = df[df['company_location'] == 'US']
df_usa.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False).head(10)
# Out:
# job_title
# Data Analytics Lead                   405000.000000
# Data Science Tech Lead                375000.000000
# Director of Data Science              294375.000000
# Principal Data Scientist              255500.000000
# Cloud Data Architect                  250000.000000
# Applied Data Scientist                238000.000000
# Head of Data                          233183.333333
# Machine Learning Software Engineer    217400.000000
# Data Lead                             212500.000000
# Head of Data Science                  202355.000000
# Name: salary_in_usd, dtype: float64
