# %% [markdown]
# # Desafío: Inferencia e hipótesis
# ## Daniel Rojas López

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



# Cargar el dataset de salarios
df = pd.read_csv("earnings.csv",delimiter=',')
df.shape
# Out:
# (1816, 15)

# %% [markdown]
# ### 1. Considerando las variables earn, height y age, vamos a suponer que nuestro dataset fuera una población completa. (Prepara los datos adecuadamente).

# %%
df.head(10)
# Out:
#    height  weight  male     earn  earnk ethnicity  education  \
# 0      74   210.0     1  50000.0   50.0     White       16.0
# 1      66   125.0     0  60000.0   60.0     White       16.0
# 2      64   126.0     0  30000.0   30.0     White       16.0
# 3      65   200.0     0  25000.0   25.0     White       17.0
# 4      63   110.0     0  50000.0   50.0     Other       16.0
# 5      68   165.0     0  62000.0   62.0     Black       18.0
# 6      63   190.0     0  51000.0   51.0     White       17.0
# 7      64   125.0     0   9000.0    9.0     White       15.0
# 8      62   200.0     0  29000.0   29.0     White       12.0
# 9      73   230.0     1  32000.0   32.0     White       17.0
#
#    mother_education  father_education  walk  exercise  smokenow  tense  angry  \
# 0              16.0              16.0     3         3       2.0    0.0    0.0
# 1              16.0              16.0     6         5       1.0    0.0    0.0
# ...

# %% [markdown]
# * Realiza 12 pruebas (4 por cada variable) con muestras de tamaño n = 25, en cada caso, con niveles de significancia diferentes pero inferiores a 0,1, para confirmar o rechazar las siguientes hipótesis considerando las alternativas. Crea para ello una fórmula que reciba los parámetros adecuados y responda "con nivel de confianza del ...%, se acepta la hipótesis nula/alternativa".
#
# ![tabla.png](tabla.png)

# %% [markdown]
# * Calcula la media poblacional para cada variable. ¿Son correctos los
# resultados obtenidos por tus pruebas?

# %% [markdown]
# ### 2. Crea una función que estime la proporción de hombres en el dataset, considerando una muestra de 50 individuos, con niveles de confianza de 95% y 99%. Escribe con palabras tus resultados al ejecutar la función e interpreta. Compara con la proporción real.

# %% [markdown]
# ### 3. Considerando el dataset como una muestra, verifica si el género (male=1 significa ‘hombre”) influye sobre el sueldo “earn” de las personas. Explica y justifica tu procedimiento
